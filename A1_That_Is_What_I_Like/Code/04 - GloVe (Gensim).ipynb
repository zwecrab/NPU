# %% [markdown]
# # GloVe (Gensim)
#
# For looking at word vectors, we'll use **Gensim**. **Gensim** isn't really a deep learning package. It's a package for for word and text similarity modeling, which started with (LDA-style) topic models and grew into SVD and neural word representations. But its efficient and scalable, and quite widely used.   We gonna use **GloVe** embeddings, downloaded at [the Glove page](https://nlp.stanford.edu/projects/glove/). They're inside [this zip file](https://nlp.stanford.edu/data/glove.6B.zip)

# %%
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models.callbacks import CallbackAny2Vec
from gensim.models import Word2Vec
import time
import numpy as np
import torch
import pickle

# %%
import nltk
from nltk.corpus import reuters
from nltk.corpus import stopwords
import string
import re

# %%
#you have to put this file in some python/gensim directory; just run it and it will inform where to put....
glove_file = datapath('glove.6B.100d.txt')  #search on the google
model = KeyedVectors.load_word2vec_format(glove_file, binary=False, no_header=True)

# %%
# Define the training corpus
corpus = reuters.sents(categories="grain")

# %%
# Save the model
model_save_path = 'model/gensim_model.pkl'
pickle.dump(model,open(model_save_path,'wb'))

# %%
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)

double_punctuation_pattern = re.compile(r'[' + re.escape(string.punctuation) + ']{2,}')

def clean_corpus(corpus):
    cleaned_corpus = []
    for sentence in corpus:
        cleaned_sentence = []
        for word in sentence:
            word = word.lower()
            if word not in stop_words and word not in punctuation and not double_punctuation_pattern.match(word):
                cleaned_sentence.append(word)
        cleaned_corpus.append(cleaned_sentence)
    return cleaned_corpus

cleaned_corpus = clean_corpus(corpus)
cleaned_corpus
# Out:
# [['china',
#   'daily',
#   'says',
#   'vermin',
#   'eat',
#   '7',
#   '12',
#   'pct',
#   'grain',
#   'stocks',
#   'survey',
#   '19',
#   'provinces',
#   'seven',
#   'cities',
#   'showed',
#   'vermin',
#   'consume',
#   'seven',
#   '12',
#   'pct',
#   'china',
#   'grain',
#   'stocks',
#   'china',
#   'daily',
#   'said'],
#  ['also',
#   'said',
#   'year',
#   '1',
#   '575',
#   'mln',
#   'tonnes',
#   '25',
#   'pct',
#   'china',
#   'fruit',
#   'output',
#   'left',
#   'rot',
#   '2',
#   '1',
#   'mln',
#   'tonnes',
#   '30',
#   'pct',
#   'vegetables'],
#  ['paper',
#   'blamed',
#   'waste',
#   'inadequate',
#   'storage',
#   'bad',
#   'preservation',
#   'methods'],
#  ['said',
#   'government',
#   'launched',
#   'national',
#   'programme',
#   'reduce',
#   'waste',
#   'calling',
#   'improved',
#   'technology',
#   'storage',
#   'preservation',
#   'greater',
#   'production',
#   'additives'],
#  ['paper', 'gave', 'details'],
#  ['thai',
#   'trade',
#   'deficit',
#   'widens',
#   'first',
#   'quarter',
#   'thailand',
#   'trade',
#   'deficit',
#   'widened',
#   '4',
#   '5',
#   'billion',
#   'baht',
#   'first',
#   'quarter',
#   '1987',
#   '2',
#   '1',
#   'billion',
#   'year',
#   'ago',
#   'business',
#   'economics',
#   'department',
#   'said'],
#  ['said',
#   'janunary',
#   'march',
#   'imports',
#   'rose',
#   '65',
#   '1',
#   'billion',
#   'baht',
#   '58',
#   '7',
#   'billion'],
#  ['thailand',
#   'improved',
#   'business',
#   'climate',
#   'year',
#   'resulted',
#   '27',
#   'pct',
#   'increase',
#   'imports',
#   'raw',
#   'materials',
#   'semi',
#   'finished',
#   'products'],
#  ['country',
#   'oil',
#   'import',
#   'bill',
#   'however',
#   'fell',
#   '23',
#   'pct',
#   'first',
#   'quarter',
#   'due',
#   'lower',
#   'oil',
#   'prices'],
#  ['department',
#   'said',
#   'first',
#   'quarter',
#   'exports',
#   'expanded',
#   '60',
#   '6',
#   'billion',
#   'baht',
#   '56',
#   '6',
#   'billion'],
#  ['export',
#   'growth',
#   'smaller',
#   'expected',
#   'due',
#   'lower',
#   'earnings',
#   'many',
#   'key',
#   'commodities',
#   'including',
#   'rice',
#   'whose',
#   'earnings',
#   'declined',
#   '18',
#   'pct',
#   'maize',
#   '66',
#   'pct',
#   'sugar',
#   '45',
#   'pct',
#   'tin',
#   '26',
#   'pct',
#   'canned',
#   'pineapples',
#   'seven',
#   'pct'],
#  ['products',
#   'registering',
#   'high',
#   'export',
#   'growth',
#   'jewellery',
#   '64',
#   'pct',
#   'clothing',
#   '57',
#   'pct',
#   'rubber',
#   '35',
#   'pct'],
#  ['sri',
#   'lanka',
#   'gets',
#   'usda',
#   'approval',
#   'wheat',
#   'price',
#   'food',
#   'department',
#   'officials',
#   'said',
#   'u',
#   'department',
#   'agriculture',
#   'approved',
#   'continental',
#   'grain',
#   'co',
#   'sale',
#   '52',
#   '500',
#   'tonnes',
#   'soft',
#   'wheat',
#   '89',
#   'u',
#   'dlrs',
#   'tonne',
#   'c',
#   'f',
#   'pacific',
#   'northwest',
#   'colombo'],
#  ['said', 'shipment', 'april', '8', '20', 'delivery'],
#  ['japan',
#   'ministry',
#   'says',
#   'open',
#   'farm',
#   'trade',
#   'would',
#   'hit',
#   'u',
#   'japan',
#   'agriculture',
#   'ministry',
#   'angered',
#   'u'],
#  ['demands',
#   'japan',
#   'open',
#   'farm',
#   'products',
#   'market',
#   'tell',
#   'u',
#   'officials',
#   'talks',
#   'later',
#   'month',
#   'liberalisation',
#   'would',
#   'harm',
#   'existing',
#   'u',
#   'farm',
#   'exports',
#   'japan',
#   'senior',
#   'ministry',
#   'official',
#   'said'],
#  ['imports',
#   'u',
#   'would',
#   'drop',
#   'due',
#   'active',
#   'sales',
#   'drives',
#   'suppliers',
#   'official',
#   'declined',
#   'named',
#   'said'],
#  ['japan',
#   'largest',
#   'customer',
#   'u',
#   'farm',
#   'products',
#   'reasonable',
#   'u',
#   'demand',
#   'japan',
#   'liberalise',
#   'farm',
#   'import',
#   'market',
#   'said'],
#  ['agriculture', 'minister', 'mutsuki', 'kato', 'said', 'u'],
#  ['insists',
#   'japan',
#   'open',
#   'protected',
#   'rice',
#   'market',
#   'also',
#   'open',
#   'wheat',
#   'market',
#   'volume',
#   'origin',
#   'regulated',
#   'protect',
#   'local',
#   'farmers'],
#  ['australia',
#   'canada',
#   'could',
#   'increase',
#   'wheat',
#   'exports',
#   'competitive',
#   'u',
#   'said'],
#  ['end',
#   'users',
#   'would',
#   'also',
#   'buy',
#   'origins',
#   'grain',
#   'traders',
#   'said'],
#  ['u',
#   'agriculture',
#   'secretary',
#   'richard',
#   'lyng',
#   'due',
#   'visit',
#   'japan',
#   'talks',
#   'april',
#   '16',
#   '27',
#   'said',
#   'ask',
#   'japan',
#   'offer',
#   'share',
#   'rice',
#   'market',
#   'u'],
#  ['suppliers', 'remove', 'quotas', 'u'],
#  ['beef', 'citrus', 'imports'],
#  ['countries', 'already', 'cutting', 'u', 'market', 'share'],
#  ['australia',
#   'largest',
#   'beef',
#   'supplier',
#   'japan',
#   'trying',
#   'boost',
#   'exports',
#   'prior',
#   'expiry',
#   'four',
#   'year',
#   'beef',
#   'accord',
#   'next',
#   'march',
#   '31'],
#  ['imports',
#   'u',
#   'corn',
#   'fallen',
#   'due',
#   'increased',
#   'sales',
#   'china',
#   'south',
#   'america',
#   'japanese',
#   'soybean',
#   'imports',
#   'brazil',
#   'expected',
#   'rise',
#   'sharply',
#   'year',
#   'although',
#   'u',
#   'remain',
#   'largest',
#   'supplier'],
#  ['u',
#   'feedgrain',
#   'sales',
#   'also',
#   'drop',
#   'japan',
#   'opens',
#   'beef',
#   'imports',
#   'since',
#   'japan',
#   'depends',
#   'almost',
#   'entirely',
#   'feedgrain',
#   'imports',
#   'mainly',
#   'u',
#   'japanese',
#   'officials',
#   'said'],
#  ['indication', 'u'],
#  ['position',
#   'came',
#   'last',
#   'december',
#   'secretary',
#   'agriculture',
#   'daniel',
#   'amstutz',
#   'said',
#   'japan',
#   'potential',
#   'provide',
#   'one',
#   'largest',
#   'boosts',
#   'u'],
#  ['agricultural',
#   'exports',
#   'beef',
#   'market',
#   'alone',
#   'representing',
#   'one',
#   'billion',
#   'dlrs',
#   'new',
#   'business'],
#  ['u',
#   'also',
#   'asked',
#   'general',
#   'agreement',
#   'tariffs',
#   'trade',
#   'investigate',
#   'legality',
#   'japanese',
#   'import',
#   'controls',
#   '12',
#   'farm',
#   'products',
#   'including',
#   'fruit',
#   'juices',
#   'purees',
#   'pulp',
#   'tomato',
#   'juice',
#   'ketchup',
#   'sauce',
#   'peanuts',
#   'prepared',
#   'beef',
#   'products',
#   'miscellaneous',
#   'beans'],
#  ['help',
#   'calm',
#   'heated',
#   'trade',
#   'relations',
#   'u',
#   'japan',
#   'top',
#   'business',
#   'group',
#   'keidanren',
#   'urged',
#   'government',
#   'remove',
#   'residual',
#   'import',
#   'restrictions',
#   'agricultural',
#   'products'],
#  ['agriculture',
#   'minister',
#   'kato',
#   'ruled',
#   'emotional',
#   'reaction',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   'farm',
#   'issue',
#   'become',
#   'scapegoat',
#   'trade',
#   'pressure',
#   'industrial',
#   'sector'],
#  ['japan',
#   'largest',
#   'buyer',
#   'u',
#   'farm',
#   'products',
#   'issues',
#   'discussed',
#   'table',
#   'official',
#   'said'],
#  ['zambia',
#   'plan',
#   'retail',
#   'maize',
#   'price',
#   'hike',
#   'zambian',
#   'government',
#   'immediate',
#   'plans',
#   'follow',
#   'last',
#   'week',
#   'increase',
#   'producer',
#   'price',
#   'maize',
#   'hike',
#   'retail',
#   'price',
#   'maize',
#   'meal',
#   'official',
#   'ruling',
#   'party',
#   'said'],
#  ['last',
#   'december',
#   '120',
#   'pct',
#   'increase',
#   'consumer',
#   'price',
#   'refined',
#   'maize',
#   'meal',
#   'zambian',
#   'staple',
#   'led',
#   'food',
#   'riots',
#   'least',
#   '15',
#   'people',
#   'died'],
#  ['price',
#   'increase',
#   'president',
#   'kenneth',
#   'kaunda',
#   'later',
#   'revoked',
#   'followed',
#   'pressure',
#   'international',
#   'monetary',
#   'fund',
#   'imf',
#   'reduce',
#   'government',
#   'subsidy',
#   'bill'],
#  ['however',
#   'producer',
#   'price',
#   'rise',
#   '6',
#   '10',
#   'dlrs',
#   '8',
#   '67',
#   'dlrs',
#   'per',
#   '90',
#   'kg',
#   'bag',
#   'accompanied',
#   'retail',
#   'price',
#   'increase',
#   'government',
#   'spend',
#   'subsidies',
#   'practice',
#   'discouraged',
#   'imf'],
#  ['way', 'raise', 'subsidy', 'levels', 'meal'],
#  ['government',
#   'would',
#   'choose',
#   'demands',
#   'imf',
#   'people',
#   'ministry',
#   'agriculture',
#   'economist',
#   'said'],
#  ['argentine',
#   'coarse',
#   'grain',
#   'losses',
#   'feared',
#   'argentine',
#   'grain',
#   'producers',
#   'adjusted',
#   'yield',
#   'estimates',
#   '1986',
#   '87',
#   'coarse',
#   'grain',
#   'crop',
#   'downward',
#   'week',
#   'yesterday',
#   'heavy',
#   'rains',
#   'end',
#   'march',
#   'beginning',
#   'april',
#   'trade',
#   'sources',
#   'said'],
#  ['said',
#   'sunflower',
#   'maize',
#   'sorghum',
#   'production',
#   'estimates',
#   'reduced',
#   'despite',
#   'later',
#   'warm',
#   'dry',
#   'weather',
#   'allowed',
#   'return',
#   'harvesting',
#   'areas'],
#  ['however',
#   'showers',
#   'fell',
#   'intermittently',
#   'last',
#   'weekend',
#   'producers',
#   'feared',
#   'another',
#   'spell',
#   'prolonged',
#   'intense',
#   'rain',
#   'could',
#   'cause',
#   'damage',
#   'crops',
#   'already',
#   'badly',
#   'hit',
#   'season'],
#  ['rains',
#   'middle',
#   'last',
#   'week',
#   'reached',
#   'average',
#   '27',
#   'millimetres',
#   'parts',
#   'buenos',
#   'aires',
#   'province',
#   '83',
#   'mm',
#   'cordoba',
#   '41',
#   'santa',
#   'fe',
#   '50',
#   'entre',
#   'rios',
#   'misiones',
#   '95',
#   'corrientes',
#   'eight',
#   'chaco',
#   '35',
#   'formosa'],
#  ['rainfall', 'period', 'la', 'pampa'],
#  ['producers',
#   'feared',
#   'continued',
#   'damp',
#   'conditions',
#   'could',
#   'produce',
#   'rotting',
#   'lead',
#   'still',
#   'lower',
#   'yield',
#   'estimates',
#   'crops',
#   'including',
#   'soybean'],
#  ['however',
#   'lands',
#   'began',
#   'drying',
#   'later',
#   'week',
#   'harvesting',
#   'advanced',
#   'considerably',
#   'reaching',
#   '36',
#   '40',
#   'pct',
#   'area',
#   'sown',
#   'case',
#   'sunflower'],
#  ['deterioration',
#   'sunflower',
#   'crop',
#   'evident',
#   'harvested',
#   'material',
#   'cordoba',
#   'la',
#   'pampa',
#   'buenos',
#   'aires',
#   'forced',
#   'yield',
#   'estimates',
#   'per',
#   'hectare',
#   'adjusted'],
#  ['season',
#   'sunflowerseed',
#   'production',
#   'forecast',
#   '2',
#   '1',
#   'mln',
#   '2',
#   '3',
#   'mln',
#   'tonnes',
#   '2',
#   '2',
#   'mln',
#   '2',
#   '4',
#   'mln',
#   'forecast',
#   'last',
#   'week',
#   '43',
#   '9',
#   '48',
#   '8',
#   'pct',
#   '1985',
#   '86',
#   'record',
#   '4',
#   '1',
#   'mln'],
#  ['area',
#   'sown',
#   'sunflowers',
#   'two',
#   '2',
#   '2',
#   'mln',
#   'hectares',
#   '29',
#   '9',
#   '36',
#   '3',
#   'pct',
#   'record',
#   '3',
#   '14',
#   'mln',
#   'hectares',
#   'last',
#   'season'],
#  ['maize', 'harvesting', 'also', 'reached', '36', '40', 'pct', 'area', 'sown'],
#  ['near',
#   'completion',
#   'cordoba',
#   'santa',
#   'fe',
#   'begin',
#   'la',
#   'pampa',
#   'southern',
#   'buenos',
#   'aires',
#   'later',
#   'april'],
#  ['production',
#   'estimates',
#   'maize',
#   'last',
#   'week',
#   '9',
#   '5',
#   'mln',
#   '9',
#   '8',
#   'mln',
#   'tonnes',
#   '9',
#   '6',
#   'mln',
#   '9',
#   '9',
#   'mln',
#   'estimated',
#   'previously'],
#  ['22',
#   '2',
#   '23',
#   '4',
#   'pct',
#   '12',
#   '4',
#   'mln',
#   '12',
#   '6',
#   'mln',
#   'tonnes',
#   'estimated',
#   'private',
#   'sources',
#   '1985',
#   '86',
#   'crop',
#   '21',
#   '9',
#   '25',
#   '8',
#   'pct',
#   'official',
#   'figure',
#   '12',
#   '8',
#   'mln',
#   'tonnes'],
#  ['maize',
#   'sown',
#   '3',
#   '58',
#   'mln',
#   '3',
#   '78',
#   'mln',
#   'hectares',
#   'two',
#   'seven',
#   'pct',
#   'last',
#   'season',
#   '3',
#   '85',
#   'mln'],
#  ['sorghum',
#   'harvested',
#   '23',
#   '25',
#   'pct',
#   'area',
#   'sown',
#   'cordoba',
#   'santa',
#   'fe',
#   'chaco'],
#  ['harvest', 'start', 'la', 'pampa', 'buenos', 'aires', 'mid', 'april'],
#  ['total',
#   'area',
#   'sown',
#   '1',
#   '23',
#   'mln',
#   '1',
#   '30',
#   'mln',
#   'hectares',
#   '10',
#   '3',
#   '15',
#   '2',
#   'pct',
#   '1',
#   '45',
#   'mln',
#   'sown',
#   'last',
#   'season'],
#  ['new',
#   'forecast',
#   'sorghum',
#   'crop',
#   '2',
#   '9',
#   'mln',
#   '3',
#   '2',
#   'mln',
#   'tonnes',
#   'compared',
#   'three',
#   'mln',
#   '3',
#   '3',
#   'mln',
#   'forecast',
#   'last',
#   'week',
#   '23',
#   '8',
#   '29',
#   '3',
#   'pct',
#   'last',
#   'season',
#   '4',
#   '1',
#   'mln',
#   '4',
#   '2',
#   'mln',
#   'tonne',
#   'crop'],
#  ['soybean',
#   'crop',
#   'season',
#   'adjusted',
#   'remaining',
#   'record',
#   '7',
#   '5',
#   'mln',
#   '7',
#   '7',
#   'mln',
#   'tonnes',
#   '4',
#   '2',
#   '5',
#   '5',
#   'pct',
#   '7',
#   '2',
#   'mln',
#   '7',
#   '3',
#   'mln',
#   'estimated',
#   'private',
#   'sources',
#   '1985',
#   '86',
#   '5',
#   '6',
#   '8',
#   '5',
#   'pct',
#   'higher',
#   'official',
#   'figure',
#   '7',
#   '1',
#   'mln'],
#  ['area',
#   'sown',
#   'soybeans',
#   'season',
#   'record',
#   '3',
#   '7',
#   'mln',
#   '3',
#   '8',
#   'mln',
#   'hectares',
#   '10',
#   '8',
#   '13',
#   '8',
#   'pct',
#   'record',
#   '3',
#   '34',
#   'mln',
#   'sown',
#   '1985',
#   '86'],
#  ['soybean',
#   'crop',
#   'showing',
#   'excessive',
#   'moisture',
#   'areas',
#   'producers',
#   'fear',
#   'may',
#   'discover',
#   'damage'],
#  ['experimental',
#   'harvesting',
#   'carried',
#   'santa',
#   'fe',
#   'areas',
#   'making',
#   'one',
#   'pct',
#   'total',
#   'crop',
#   'details',
#   'available'],
#  ['preparation',
#   'fields',
#   '1987',
#   '88',
#   'wheat',
#   'crop',
#   'sown',
#   'may',
#   'august',
#   'september',
#   'far',
#   'intense',
#   'previous',
#   'years'],
#  ['honduras',
#   'seeking',
#   'pl',
#   '480',
#   'bulk',
#   'wheat',
#   'april',
#   '13',
#   'honduras',
#   'tender',
#   'april',
#   '13',
#   'public',
#   'law',
#   '480',
#   'approximately',
#   '52',
#   '500',
#   'tonnes',
#   'various',
#   'wheats',
#   'bulk',
#   'agent',
#   'country',
#   'said'],
#  ['agent', 'said', 'honduras', 'seeking', 'u'],
#  ['2',
#   'better',
#   'northern',
#   'spring',
#   'dns',
#   '14',
#   'pct',
#   'protein',
#   'minimum',
#   '13',
#   'pct',
#   'moisture',
#   'maximum',
#   'u'],
#  ['2',
#   'better',
#   'hard',
#   'red',
#   'winter',
#   '12',
#   'pct',
#   'protein',
#   'minimum',
#   '13',
#   'pct',
#   'moisture',
#   'maximum'],
#  ['agent',
#   'said',
#   'ns',
#   'dns',
#   'laydays',
#   'include',
#   'july',
#   '1',
#   '10',
#   '7',
#   '500',
#   '9',
#   '500',
#   'tonnes',
#   'aug',
#   '1',
#   '10',
#   '8',
#   '000',
#   '10',
#   '000',
#   'tonnes',
#   'sept',
#   '15',
#   '25',
#   '12',
#   '500',
#   '14',
#   '500',
#   'tonnes'],
#  ['hrw',
#   'laydays',
#   'include',
#   'june',
#   '20',
#   '30',
#   '5',
#   '000',
#   '7',
#   '000',
#   'tonnes',
#   'july',
#   '15',
#   '25',
#   '6',
#   '500',
#   '8',
#   '500',
#   'tonnes',
#   'september',
#   '15',
#   '25',
#   '7',
#   '000',
#   '9',
#   '000',
#   'tonnes'],
#  ['offers',
#   'due',
#   '1550',
#   'hrs',
#   'edt',
#   'april',
#   '13',
#   'remain',
#   'valid',
#   '1000',
#   'hrs',
#   'edt',
#   'april',
#   '14',
#   'agent',
#   'said'],
#  ['brazil',
#   'grain',
#   'harvest',
#   'faces',
#   'storage',
#   'problems',
#   'storage',
#   'problems',
#   'brazil',
#   'record',
#   'grain',
#   'crop',
#   'likely',
#   'result',
#   'losses',
#   'five',
#   'mln',
#   'tonnes',
#   'agriculture',
#   'ministry',
#   'spokesman',
#   'said'],
#  ['ministry',
#   'spokesman',
#   'leonardo',
#   'brito',
#   'speaking',
#   'brasilia',
#   'told',
#   'reuters',
#   'believed',
#   'five',
#   'mln',
#   'tonnes',
#   'year',
#   'estimated',
#   'crop',
#   '65',
#   'mln',
#   'tonnes',
#   'would',
#   'lost'],
#  ['said',
#   'part',
#   'would',
#   'normal',
#   'loss',
#   'inevitable',
#   'harvesting',
#   'would',
#   'stem',
#   'storage',
#   'problems'],
#  ['brazil',
#   'storage',
#   'capacity',
#   '66',
#   'mln',
#   'tonnes',
#   'theoretically',
#   'sufficient',
#   'crop'],
#  ['brito', 'said', 'storage', 'capacity', 'badly', 'distributed'],
#  ['states',
#   'sao',
#   'paulo',
#   'parana',
#   'rio',
#   'grande',
#   'sul',
#   '70',
#   'pct',
#   'nation',
#   'capacity',
#   'responsible',
#   '50',
#   '60',
#   'pct',
#   'production'],
#  ['biggest',
#   'problems',
#   'concentrated',
#   'centre',
#   'west',
#   'growing',
#   'regions',
#   'rising',
#   'production',
#   'outpaced',
#   'storage',
#   'capacity'],
#  ['brito',
#   'said',
#   'centre',
#   'west',
#   'whose',
#   'crops',
#   'include',
#   'soya',
#   'maize',
#   '30',
#   '40',
#   'pct',
#   'nation',
#   'grains',
#   'production',
#   '20',
#   'pct',
#   'storage',
#   'space'],
#  ['addition',
#   'poor',
#   'distribution',
#   'storage',
#   'units',
#   'problem',
#   'much',
#   'capacity',
#   'geared',
#   'storing',
#   'grain',
#   'sacks',
#   'enough',
#   'suitable',
#   'storing',
#   'loose',
#   'grain',
#   'brito',
#   'said'],
#  ['finally', 'shortage', 'lorries', 'transport', 'crops'],
#  ['sheer',
#   'scale',
#   'task',
#   'transporting',
#   'record',
#   'crop',
#   'evident',
#   'television',
#   'reports',
#   'shown',
#   'enormous',
#   'queues',
#   'lorries',
#   'waiting',
#   'outside',
#   'granaries'],
#  ['tunisia',
#   'expected',
#   'tender',
#   'french',
#   'wheat',
#   'tunisia',
#   'expected',
#   'tender',
#   'april',
#   '14',
#   '100',
#   '000',
#   'tonnes',
#   'french',
#   'soft',
#   'wheat',
#   'delivery',
#   'may',
#   'august',
#   'would',
#   'covered',
#   'french',
#   'export',
#   'credit',
#   'agency',
#   'coface',
#   'export',
#   'credits',
#   'traders',
#   'said'],
#  ['official', 'tender', 'announced', 'yet', 'tunisia', 'said'],
#  ['france',
#   'sold',
#   'total',
#   '200',
#   '000',
#   'tonnes',
#   'soft',
#   'wheat',
#   'tunisia',
#   'since',
#   'begining',
#   'current',
#   'campaign',
#   'covered',
#   'coface',
#   'export',
#   'credits'],
#  ['amount', 'total', '150', '000', 'tonnes', 'exported', 'march', '1', 'said'],
#  ['ccc',
#   'accepts',
#   'export',
#   'bid',
#   'wheat',
#   'flour',
#   'iraq',
#   'commodity',
#   'credit',
#   'corporation',
#   'accepted',
#   'bid',
#   'export',
#   'bonus',
#   'cover',
#   'sale',
#   '12',
#   '500',
#   'tonnes',
#   'wheat',
#   'flour',
#   'iraq',
#   'u',
#   'agriculture',
#   'department',
#   'said'],
#  ['bonus',
#   'awarded',
#   '113',
#   '0',
#   'dlrs',
#   'per',
#   'tonne',
#   'paid',
#   'peavey',
#   'company',
#   'form',
#   'commodities',
#   'ccc',
#   'stocks'],
#  ['wheat',
#   'flour',
#   'delivery',
#   'may',
#   '15',
#   'june',
#   '15',
#   '1987',
#   'department',
#   'said'],
#  ['additional',
#   '162',
#   '500',
#   'tonnes',
#   'wheat',
#   'flour',
#   'still',
#   'available',
#   'iraq',
#   'export',
#   'enhancement',
#   'program',
#   'initiative',
#   'announced',
#   'january',
#   '7',
#   '1987',
#   'usda',
#   'said'],
#  ['egypt',
#   'authorized',
#   'buy',
#   'pl',
#   '480',
#   'wheat',
#   'usda',
#   'egypt',
#   'authorized',
#   'purchase',
#   '200',
#   '000',
#   'tonnes',
#   'u',
#   'wheat',
#   'existing',
#   'pl',
#   '480',
#   'agreement',
#   'u',
#   'agriculture',
#   'department',
#   'said'],
#  ['may',
#   'buy',
#   'wheat',
#   'valued',
#   '22',
#   '0',
#   'mln',
#   'dlrs',
#   'april',
#   '15',
#   'august',
#   '31',
#   '1987',
#   'ship',
#   'u',
#   'ports',
#   'september',
#   '30',
#   'department',
#   'said'],
#  ['south',
#   'korea',
#   'corn',
#   'imports',
#   'may',
#   'increase',
#   'usda',
#   'south',
#   'korea',
#   'purchase',
#   '2',
#   '4',
#   'mln',
#   'tonnes',
#   'u',
#   'corn',
#   'past',
#   'six',
#   'months',
#   'close',
#   'double',
#   'last',
#   'year',
#   'total',
#   'indicates',
#   'imports',
#   'united',
#   'states',
#   'well',
#   'total',
#   'imports',
#   'set',
#   'dramatic',
#   'jump',
#   'u',
#   'agriculture',
#   'department',
#   'said'],
#  ['world',
#   'production',
#   'trade',
#   'report',
#   'department',
#   'said',
#   'total',
#   'south',
#   'korea',
#   'corn',
#   'imports',
#   '1986',
#   '87',
#   'season',
#   'oct',
#   'sept',
#   'estimated',
#   '4',
#   '3',
#   'mln',
#   'tonnes',
#   '3',
#   '4',
#   'mln',
#   'tonnes',
#   'united',
#   'states'],
#  ['1985',
#   '86',
#   'season',
#   'imports',
#   'totaled',
#   '1',
#   '3',
#   'mln',
#   'tonnes',
#   'u',
#   'corn',
#   'total',
#   '3',
#   '6',
#   'mln',
#   'tonnes'],
#  ['ite',
#   'appears',
#   'koreans',
#   'shifting',
#   'back',
#   'u',
#   'corn',
#   'light',
#   'competitive',
#   'u',
#   'prices',
#   'uncertain',
#   'supplies',
#   'china',
#   'argentina',
#   'south',
#   'africa',
#   'said'],
#  ['usda',
#   'seeks',
#   'comments',
#   'grain',
#   'discount',
#   'schedule',
#   'u',
#   'agriculture',
#   'department',
#   'seeking',
#   'public',
#   'comments',
#   'question',
#   'adjusting',
#   'commodity',
#   'credit',
#   'corporation',
#   'ccc',
#   'discount',
#   'premium',
#   'schedules',
#   'improve',
#   'quality',
#   'grain',
#   'accepts',
#   'loan',
#   'collateral',
#   'price',
#   'support',
#   'programs'],
#  ['premiums',
#   'discounts',
#   'schedule',
#   'based',
#   'quality',
#   'factors',
#   'moisture',
#   'content',
#   'kernel',
#   'damage'],
#  ['schedule',
#   'stipulates',
#   'premiums',
#   'discounts',
#   'used',
#   'valuing',
#   'grain',
#   'ccc',
#   'accepts',
#   'purchases',
#   'year'],
#  ['department',
#   'said',
#   'possible',
#   'producers',
#   'could',
#   'encouraged',
#   'delivery',
#   'higher',
#   'quality',
#   'grain',
#   'ccc',
#   'adjusting',
#   'premiums',
#   'discounts'],
#  ['comments',
#   'due',
#   'april',
#   '24',
#   'report',
#   'congress',
#   'required',
#   'law',
#   'may',
#   '10'],
#  ['usda',
#   'discussing',
#   'pl',
#   '480',
#   'agreement',
#   'morocco',
#   'u',
#   'agriculture',
#   'department',
#   'currently',
#   'discussing',
#   'amendment',
#   'pl',
#   '480',
#   'agreement',
#   'signed',
#   'morocco',
#   'january',
#   '22',
#   'mix',
#   'commodities',
#   'amendment',
#   'determined',
#   'u',
#   'agriculture',
#   'department',
#   'official',
#   'said'],
#  ['official',
#   'noted',
#   'agreement',
#   'signed',
#   'january',
#   'provided',
#   'supply',
#   '55',
#   '000',
#   'tonnes',
#   'vegetable',
#   'oil',
#   '55',
#   '000',
#   'tonnes',
#   'corn',
#   '126',
#   '000',
#   'tonnes',
#   'wheat',
#   'delivery',
#   'current',
#   'fiscal',
#   'year',
#   'ending',
#   'september',
#   '30'],
#  ['purchase',
#   'authorizations',
#   'commodities',
#   'provided',
#   'january',
#   'agreement',
#   'announced',
#   'department'],
#  ['japan',
#   'ministry',
#   'comment',
#   'rice',
#   'talks',
#   'report',
#   'agriculture',
#   'ministry',
#   'declined',
#   'comment',
#   'local',
#   'newspaper',
#   'report',
#   'japan',
#   'agreed',
#   'hold',
#   'talks',
#   'closed',
#   'rice',
#   'market',
#   'new',
#   'gatt',
#   'round'],
#  ['idea', 'report', 'cannot', 'comment', 'spokesman', 'told', 'reuters'],
#  ['nihon',
#   'keizai',
#   'shinbun',
#   'quoting',
#   'unnamed',
#   'government',
#   'sources',
#   'said',
#   'japan',
#   'would',
#   'tell',
#   'u',
#   'agriculture',
#   'secretary',
#   'richard',
#   'lyng',
#   'u',
#   'trade',
#   'representative',
#   'clayton',
#   'yeutter',
#   'intentions'],
#  ['two', 'due', 'visit', 'japan', 'later', 'month', 'farm', 'talks'],
#  ['u',
#   'pressing',
#   'japan',
#   'discuss',
#   'rice',
#   'issue',
#   'new',
#   'round',
#   'general',
#   'agreement',
#   'tariffs',
#   'trade',
#   'talks'],
#  ['japan', 'said', 'gatt', 'right', 'forum'],
#  ['imports', 'rice', 'japan', 'banned', 'foodstuff', 'control', 'act'],
#  ['nihon',
#   'keizai',
#   'said',
#   'japan',
#   'plan',
#   'resulted',
#   'worries',
#   'mounting',
#   'trade',
#   'tension',
#   'u',
#   'gatt',
#   'talks',
#   'japan',
#   'try',
#   'persuade',
#   'u',
#   'rice',
#   'policy',
#   'justified',
#   'said'],
#  ['93',
#   'nation',
#   'world',
#   'trade',
#   'body',
#   'began',
#   'uruguay',
#   'trade',
#   'round',
#   'last',
#   'september'],
#  ['take', 'four', 'years', 'negotiate'],
#  ['china',
#   'wheat',
#   'crop',
#   'threatened',
#   'pests',
#   'disease',
#   'pests',
#   'disease',
#   'destroyed',
#   '1',
#   '1',
#   'mln',
#   'tonnes',
#   'wheat',
#   'china',
#   '1986',
#   'threatening',
#   'crops',
#   '11',
#   '64',
#   'mln',
#   'hectares',
#   'year',
#   'china',
#   'daily',
#   'said'],
#  ['14', '54', 'mln', 'hectares', 'wheat', 'affected', '1986'],
#  ['paper',
#   'said',
#   'abnormal',
#   'weather',
#   'conditions',
#   'encouraged',
#   'spread',
#   'wheat',
#   'midges',
#   '2',
#   '47',
#   'mln',
#   'hectares',
#   'shanxi',
#   'henan',
#   'sichuan',
#   'anhui',
#   'hebei',
#   'jiangsu'],
#  ['henan',
#   'shandong',
#   'hebei',
#   'wheat',
#   'aphids',
#   'affecting',
#   '4',
#   '67',
#   'mln',
#   'hectares',
#   'wheat',
#   'red',
#   'mite',
#   '2',
#   '8',
#   'mln',
#   'hectares',
#   'wheat',
#   'powdery',
#   'mildew',
#   '1',
#   '7',
#   'mln',
#   'hectares'],
#  ['fao',
#   'sees',
#   'lower',
#   'global',
#   'wheat',
#   'grain',
#   'output',
#   '1987',
#   'u',
#   'n',
#   'food',
#   'agriculture',
#   'organisation',
#   'fao',
#   'said',
#   'global',
#   'wheat',
#   'coarse',
#   'grain',
#   'output',
#   'likely',
#   'fall',
#   '1987',
#   'supplies',
#   'would',
#   'remain',
#   'adequate',
#   'meet',
#   'demand'],
#  ['fao',
#   'said',
#   'monthly',
#   'food',
#   'outlook',
#   'bulletin',
#   'total',
#   'world',
#   'grain',
#   'output',
#   'expected',
#   'fall',
#   '38',
#   'mln',
#   'tonnes',
#   '1',
#   '353',
#   'mln',
#   '1987',
#   'due',
#   'mainly',
#   'unusually',
#   'high',
#   'winter',
#   'losses',
#   'soviet',
#   'union',
#   'drought',
#   'china',
#   'reduced',
#   'plantings',
#   'north',
#   'america'],
#  ['world',
#   'cereal',
#   'stocks',
#   'end',
#   '1986',
#   '87',
#   'forecast',
#   'rise',
#   '47',
#   'mln',
#   'tonnes',
#   'record',
#   '452',
#   'mln',
#   'tonnes',
#   'softening',
#   'impact',
#   'reduced',
#   'production'],
#  ['stocks',
#   'unevenly',
#   'distributed',
#   '50',
#   'pct',
#   'held',
#   'u',
#   'thus',
#   'food',
#   'security',
#   'prospects',
#   '1987',
#   '88',
#   'many',
#   'developing',
#   'countries',
#   'particularly',
#   'africa',
#   'depend',
#   'crucially',
#   'outcome',
#   'year',
#   'harvests',
#   'fao',
#   'said'],
#  ['fao',
#   'said',
#   'world',
#   'cereal',
#   'supplies',
#   '1986',
#   '87',
#   'estimated',
#   'record',
#   '2',
#   '113',
#   'mln',
#   'tonnes',
#   'five',
#   'pct',
#   'higher',
#   'last',
#   'season',
#   'due',
#   'mainly',
#   'large',
#   'stocks',
#   'record',
#   '1986',
#   'harvest',
#   'estimated',
#   '1',
#   '865',
#   'mln',
#   'tonnes'],
#  ['fao',
#   'forecast',
#   '1986',
#   '87',
#   'world',
#   'cereals',
#   'trade',
#   'revised',
#   'upwards',
#   'eight',
#   'mln',
#   'tonnes',
#   '179',
#   'mln',
#   'due',
#   'likelihood',
#   'substantial',
#   'buying',
#   'china',
#   'soviet',
#   'union'],
#  ['rpt',
#   'argentine',
#   'grain',
#   'oilseed',
#   'export',
#   'prices',
#   'adjusted',
#   'argentine',
#   'grain',
#   'board',
#   'adjusted',
#   'minimum',
#   'export',
#   'prices',
#   'grain',
#   'oilseed',
#   'products',
#   'dlrs',
#   'per',
#   'tonne',
#   'fob',
#   'previous',
#   'brackets',
#   'follows',
#   'sorghum',
#   '64',
#   '63',
#   'sunflowerseed',
#   'cake',
#   'expellers',
#   '103',
#   '102',
#   'pellets',
#   '101',
#   '100',
#   'meal',
#   '99',
#   '98',
#   'linseed',
#   'oil',
#   '274',
#   '264',
#   'groundnutseed',
#   'oil',
#   '450',
#   '445',
#   'soybean',
#   'oil',
#   '300',
#   '290',
#   'rapeseed',
#   'oil',
#   '290',
#   '280'],
#  ['sunflowerseed',
#   'oil',
#   'shipment',
#   'may',
#   '323',
#   '313',
#   'june',
#   'onwards',
#   '330',
#   '320'],
#  ['board',
#   'also',
#   'adjusted',
#   'export',
#   'prices',
#   'export',
#   'taxes',
#   'levied',
#   'dlrs',
#   'per',
#   'tonne',
#   'fob',
#   'previous',
#   'brackets',
#   'follows',
#   'bran',
#   'pollard',
#   'wheat',
#   '40',
#   '42',
#   'pellets',
#   '42',
#   '44'],
#  ['london', 'freight', 'market', 'features', 'grain', 'u'],
#  ['moderately', 'active', 'grain', 'fixing', 'reported', 'u'],
#  ['none',
#   'business',
#   'involved',
#   'significant',
#   'voyages',
#   'continent',
#   'japan',
#   'ship',
#   'brokers',
#   'said'],
#  ['steady',
#   '13',
#   '50',
#   'dlrs',
#   'paid',
#   'u',
#   'gulf',
#   'morocco',
#   '23',
#   '25',
#   'dlrs',
#   'paid',
#   '27',
#   '000',
#   'long',
#   'tons',
#   'gulf',
#   'taiwan'],
#  ['vessel',
#   'carrying',
#   '13',
#   '500',
#   'long',
#   'tons',
#   'bagged',
#   'wheat',
#   'flour',
#   'gulf',
#   'aqaba',
#   'received',
#   'lump',
#   'sum',
#   '472',
#   '500',
#   'dlrs'],
#  ['grain',
#   'great',
#   'lakes',
#   'algeria',
#   'made',
#   '28',
#   'dlrs',
#   '27',
#   '75',
#   'paid',
#   'similar',
#   'fixing',
#   'towards',
#   'end',
#   'march'],
#  ['market',
#   'talk',
#   'suggested',
#   'federal',
#   'commerce',
#   'vessel',
#   'booked',
#   'move',
#   'grain',
#   'great',
#   'lakes',
#   'morocco',
#   'comanav',
#   'account',
#   '22',
#   'dlrs',
#   '15',
#   '50',
#   'paid',
#   'cargo',
#   'oilseeds',
#   'british',
#   'columbia',
#   'japan',
#   'confirmation',
#   'obtainable'],
#  ['continent',
#   'shippers',
#   'agreed',
#   '19',
#   'dlrs',
#   'wheat',
#   'la',
#   'pallice',
#   'buenaventura',
#   '10',
#   '75',
#   'dlrs',
#   'grain',
#   'ghent',
#   'naples',
#   'venice',
#   'range'],
#  ['elsewhere', 'maize', 'east', 'london', 'japan', 'paid', '22', 'dlrs'],
#  ['soviet',
#   'charterers',
#   'reappeared',
#   'timecharter',
#   'sector',
#   'secured',
#   '30',
#   '000',
#   'tonner',
#   'savona',
#   'trans',
#   'atlantic',
#   'round',
#   'trip',
#   '4',
#   '450',
#   'dlrs',
#   'daily',
#   '31',
#   '000',
#   'tonner',
#   'antwerp',
#   'hamburg',
#   'similar',
#   'voyage',
#   '4',
#   '250',
#   'dlrs',
#   'daily'],
#  ['india',
#   'foodgrain',
#   'target',
#   '160',
#   'mln',
#   'tonnes',
#   '1987',
#   '88',
#   'india',
#   'national',
#   'foodgrain',
#   'target',
#   'fixed',
#   '160',
#   'mln',
#   'tonnes',
#   '1987',
#   '88',
#   'apr',
#   'mar',
#   'unchanged',
#   '1986',
#   '87',
#   'target',
#   'agriculture',
#   'ministry',
#   'said',
#   'annual',
#   'report',
#   '1986',
#   '87'],
#  ['actual',
#   'output',
#   'estimated',
#   '151',
#   'mln',
#   'tonnes',
#   '1986',
#   '87',
#   'due',
#   'failure',
#   'monsoon',
#   'rains',
#   '15',
#   '35',
#   'meterological',
#   'sub',
#   'divisions',
#   'country'],
#  ['report',
#   'gave',
#   'targets',
#   'various',
#   'crops',
#   'estimated',
#   'harvested',
#   'crops',
#   '1986',
#   '87',
#   'brackets',
#   'following',
#   'mln',
#   'tonnes',
#   'rice',
#   '65',
#   '60',
#   'wheat',
#   '49',
#   '49',
#   'coarse',
#   'grains',
#   'including',
#   'sorghum',
#   'millets',
#   '32',
#   '29',
#   'pulses',
#   '14',
#   '13'],
#  ['despite',
#   'failure',
#   'monsoon',
#   'rains',
#   'recent',
#   'years',
#   'possible',
#   'maintain',
#   'higher',
#   'foodgrain',
#   'production',
#   'signifying',
#   'growing',
#   'resilience',
#   'agricultural',
#   'sector',
#   'report',
#   'said'],
#  ['strategy',
#   'increasing',
#   'irrigation',
#   'potential',
#   'along',
#   'greater',
#   'use',
#   'high',
#   'yielding',
#   'seed',
#   'varieites',
#   'improvement',
#   'fertiliser',
#   'efficiency',
#   'yielding',
#   'results',
#   'said',
#   'adding',
#   'total',
#   'foodgrain',
#   'output',
#   '1985',
#   '86',
#   '1984',
#   '85',
#   '1983',
#   '84',
#   'respectively',
#   '150',
#   '5',
#   'mln',
#   'tonnes',
#   '145',
#   '5',
#   'mln',
#   'record',
#   '152',
#   '4',
#   'mln'],
#  ['india',
#   'targeted',
#   'produce',
#   '178',
#   '183',
#   'mln',
#   'tonnes',
#   'foodgrains',
#   'last',
#   'year',
#   'seventh',
#   'five',
#   'year',
#   'development',
#   'plan',
#   'ending',
#   'march',
#   '31',
#   '1990'],
#  ['taking',
#   'midpoint',
#   '180',
#   'mln',
#   'tonnes',
#   'target',
#   '1986',
#   '87',
#   'estimated',
#   'production',
#   'around',
#   '151',
#   'mln',
#   'tonnes',
#   'gap',
#   '29',
#   'mln',
#   'tonnes',
#   'made',
#   'remaining',
#   'three',
#   'years',
#   'plan',
#   'increasing',
#   'grain',
#   'output',
#   'annually',
#   'nine',
#   'mln',
#   'tonnes'],
#  ['target', 'achieved', 'good', 'weather', 'report', 'said'],
#  ['major',
#   'thrust',
#   'programme',
#   'therefore',
#   'better',
#   'water',
#   'irrigation',
#   'management'],
#  ['simultaneously',
#   'efforts',
#   'spread',
#   'improved',
#   'technology',
#   'including',
#   'timely',
#   'use',
#   'inputs',
#   'farm',
#   'materials',
#   'like',
#   'fertilisers',
#   'adequate',
#   'quantities',
#   'vigrously',
#   'pursued',
#   'said'],
#  ['egypt',
#   'buys',
#   'pl',
#   '480',
#   'wheat',
#   'flour',
#   'u',
#   'traders',
#   'egypt',
#   'bought',
#   '125',
#   '723',
#   'tonnes',
#   'u',
#   'wheat',
#   'flour',
#   'pl',
#   '480',
#   'tender',
#   'yesterday',
#   'trade',
#   'sources',
#   'said'],
#  ['purchase',
#   'included',
#   '51',
#   '880',
#   'tonnes',
#   'may',
#   'shipment',
#   '73',
#   '843',
#   'tonnes',
#   'june',
#   'shipment'],
#  ['price', 'details', 'available'],
#  ['argentine',
#   'grain',
#   'belt',
#   'weather',
#   'report',
#   'argentine',
#   'grain',
#   'belt',
#   'temperatures',
#   'centigrade',
#   'rain',
#   'mm',
#   '24',
#   'hours',
#   '12',
#   '00',
#   'gmt',
#   'max',
#   'temp',
#   'min',
#   'temp',
#   'rainfall',
#   'buenos',
#   'aires',
#   '24',
#   '12',
#   '0',
#   'bahia',
#   'blanca',
#   '22',
#   '7',
#   '0',
#   'tres',
#   'arroyos',
#   '22',
#   '8',
#   '0',
#   'tandil',
#   '22',
#   '7',
#   '0',
#   'junin',
#   '24',
#   '11',
#   '0',
#   'santa',
#   'rosa',
#   '6',
#   '0',
#   'cordoba',
#   '23',
#   '12',
#   '1',
#   'santa',
#   'fe',
#   '21',
#   '18',
#   '17',
#   'reuter'],
#  ['yugoslavia',
#   'tender',
#   '100',
#   '000',
#   'tonnes',
#   'wheat',
#   'yugoslavia',
#   'tender',
#   'april',
#   '14',
#   '100',
#   '000',
#   'tonnes',
#   'wheat',
#   'u',
#   'agriculture',
#   'department',
#   'counselor',
#   'belgrade',
#   'said',
#   'field',
#   'report'],
#  ['report',
#   'dated',
#   'april',
#   '7',
#   'said',
#   'wheat',
#   'must',
#   '1986',
#   '1987',
#   'harvest',
#   'imports',
#   'soft',
#   'wheat',
#   'europe',
#   'suppliers',
#   'considered'],
#  ['said',
#   'imports',
#   'used',
#   'rebuild',
#   'federal',
#   'reserves',
#   'result',
#   'subject',
#   'import',
#   'surcharges'],
#  ['french',
#   'free',
#   'market',
#   'cereal',
#   'export',
#   'bids',
#   'detailed',
#   'french',
#   'operators',
#   'requested',
#   'licences',
#   'export',
#   '320',
#   '000',
#   'tonnes',
#   'free',
#   'market',
#   'barley',
#   '225',
#   '000',
#   'tonnes',
#   'maize',
#   '25',
#   '000',
#   'tonnes',
#   'free',
#   'market',
#   'bread',
#   'making',
#   'wheat',
#   '20',
#   '000',
#   'tonnes',
#   'feed',
#   'wheat',
#   'today',
#   'ec',
#   'tender',
#   'trade',
#   'sources',
#   'said'],
#  ['barley',
#   'rebates',
#   '138',
#   '141',
#   '25',
#   'european',
#   'currency',
#   'units',
#   'ecus',
#   'per',
#   'tonne',
#   'sought',
#   'maize',
#   '129',
#   '65',
#   '139',
#   'ecus',
#   'bread',
#   'making',
#   'wheat',
#   'around',
#   '145',
#   'ecus',
#   'feed',
#   'wheat',
#   'around',
#   '142',
#   '45',
#   'ecus'],
#  ['barley',
#   'rebates',
#   '138',
#   '50',
#   'ecus',
#   'requested',
#   'total',
#   '40',
#   '000',
#   'tonnes',
#   '139',
#   'ecus',
#   '85',
#   '000',
#   'tonnes'],
#  ['rebates',
#   '130',
#   'ecus',
#   'per',
#   'tonne',
#   'requested',
#   'total',
#   '55',
#   '000',
#   'tonnes',
#   'maize',
#   '131',
#   'ecus',
#   '105',
#   '000',
#   'tonnes',
#   'sources',
#   'said'],
#  ['ec',
#   'authorises',
#   'export',
#   '55',
#   '000',
#   'tonnes',
#   'maize',
#   'maximum',
#   'rebate',
#   '130',
#   'ecus',
#   'tonne',
#   'trade',
#   'sources'],
#  ['ec',
#   'authorises',
#   'export',
#   '55',
#   '000',
#   'tonnes',
#   'maize',
#   'maximum',
#   'rebate',
#   '130',
#   'ecus',
#   'tonne',
#   'trade',
#   'sources'],
#  ['ec',
#   'authorises',
#   'export',
#   '65',
#   '000',
#   'tonnes',
#   'barley',
#   'maximum',
#   'rebate',
#   '138',
#   '75',
#   'ecus',
#   'brussels',
#   'trade'],
#  ['ec',
#   'authorises',
#   'export',
#   '65',
#   '000',
#   'tonnes',
#   'barley',
#   'maximum',
#   'rebate',
#   '138',
#   '75',
#   'ecus',
#   'brussels',
#   'trade'],
#  ['ec',
#   'grants',
#   'free',
#   'market',
#   'barley',
#   'maize',
#   'exports',
#   'european',
#   'commission',
#   'authorised',
#   'export',
#   '65',
#   '000',
#   'tonnes',
#   'free',
#   'market',
#   'barley',
#   'today',
#   'tender',
#   'maximum',
#   'rebate',
#   '138',
#   '75',
#   'european',
#   'currency',
#   'units',
#   '55',
#   '000',
#   'tonnes',
#   'french',
#   'maize',
#   '130',
#   'ecus',
#   'grain',
#   'traders',
#   'said'],
#  ['rejected', 'bids', 'breadmaking', 'feed', 'wheat', 'said'],
#  ['brazil',
#   'soybean',
#   'yields',
#   'seen',
#   'average',
#   'usda',
#   'report',
#   'based',
#   'field',
#   'travel',
#   'brazilian',
#   'state',
#   'parana',
#   'soybean',
#   'yields',
#   'average',
#   '2',
#   '0',
#   '2',
#   '2',
#   'tonnes',
#   'per',
#   'hectare',
#   'u',
#   'agriculture',
#   'department',
#   'officer',
#   'sao',
#   'paulo',
#   'said',
#   'field',
#   'report'],
#  ['report',
#   'dated',
#   'march',
#   '24',
#   'noted',
#   'parana',
#   'accounts',
#   '20',
#   '24',
#   'pct',
#   'brazil',
#   'total',
#   'soybean',
#   'crop'],
#  ['said',
#   'generally',
#   'favorable',
#   'weather',
#   'early',
#   'december',
#   'february',
#   'helped',
#   'compensate',
#   'earlier',
#   'dryness'],
#  ['however',
#   'hot',
#   'dry',
#   'weather',
#   'past',
#   '20',
#   '30',
#   'days',
#   'followed',
#   'unseasonably',
#   'brief',
#   'cold',
#   'spell',
#   'second',
#   'week',
#   'march',
#   'raised',
#   'concern',
#   'late',
#   'planted',
#   'soybeans',
#   'still',
#   'immature',
#   'impact',
#   'may',
#   'localized',
#   'report',
#   'said'],
#  ['corn',
#   'crop',
#   'expected',
#   'record',
#   'create',
#   'serious',
#   'storage',
#   'problems',
#   'report',
#   'said'],
#  ['due',
#   'favorable',
#   'support',
#   'prices',
#   'corn',
#   'area',
#   'increased',
#   '25',
#   'pct',
#   'expense',
#   'soybeans',
#   'yields',
#   'expected',
#   'average',
#   'said'],
#  ['due',
#   'late',
#   'plantings',
#   '20',
#   'pct',
#   'corn',
#   'crop',
#   'crop',
#   'harvested'],
#  ['field',
#   'trip',
#   'long',
#   'truck',
#   'lines',
#   'noted',
#   'grain',
#   'elevators',
#   'preference',
#   'given',
#   'soybeans',
#   'corn',
#   'report',
#   'said'],
#  ['new',
#   'crop',
#   'wheat',
#   'plantings',
#   'expected',
#   'decline',
#   'parana',
#   'accounts',
#   '60',
#   'pct',
#   'total',
#   'production'],
#  ['major',
#   'reasons',
#   'decline',
#   'expected',
#   'reduced',
#   'government',
#   'support',
#   'price',
#   'good',
#   'summer',
#   'crop',
#   'harvests'],
#  ['grain',
#   'ships',
#   'waiting',
#   'new',
#   'orleans',
#   'ten',
#   'grain',
#   'ships',
#   'loading',
#   '14',
#   'waiting',
#   'load',
#   'new',
#   'orleans',
#   'elevators',
#   'trade',
#   'sources',
#   'said'],
#  ['elevator',
#   'loading',
#   'waiting',
#   'continental',
#   'grain',
#   'westwego',
#   '1',
#   '6',
#   'mississippi',
#   'river',
#   'myrtle',
#   'grove',
#   '1',
#   '0',
#   'adm',
#   'growmark',
#   '1',
#   '4',
#   'bunge',
#   'grain',
#   'destrehan',
#   '1',
#   '0',
#   'elevator',
#   'loading',
#   'waiting',
#   'st',
#   'charles',
#   'destrehan',
#   '1',
#   '1',
#   'reserve',
#   'elevator',
#   'corp',
#   '1',
#   '0',
#   'peavey',
#   'co',
#   'st',
#   'elmo',
#   '1',
#   '0',
#   'cargill',
#   'grain',
#   'terre',
#   'haute',
#   '2',
#   '1',
#   'cargill',
#   'grain',
#   'port',
#   'allen',
#   '0',
#   '0',
#   'zen',
#   'noh',
#   '1',
#   '2'],
#  ['ec',
#   'commission',
#   'authorised',
#   'buy',
#   'maize',
#   'june',
#   'european',
#   'commission',
#   'authorised',
#   'buy',
#   'one',
#   'mln',
#   'tonnes',
#   'maize',
#   'intervention',
#   'stores',
#   'second',
#   'half',
#   'june',
#   'although',
#   'sales',
#   'intervention',
#   'normally',
#   'end',
#   'april',
#   '30',
#   'commission',
#   'sources',
#   'said'],
#  ['said',
#   'approval',
#   'given',
#   'ec',
#   'cereals',
#   'management',
#   'committee',
#   'possible',
#   'disturbance',
#   'market',
#   'due',
#   'heavy',
#   'imports',
#   'maize',
#   'agreement',
#   'ec',
#   'united',
#   'states'],
#  ['agreement',
#   'guarantees',
#   'access',
#   'spanish',
#   'market',
#   'two',
#   'mln',
#   'tonnes',
#   'non',
#   'ec',
#   'maize',
#   'year',
#   'next',
#   'four',
#   'years'],
#  ['sources',
#   'said',
#   'intervention',
#   'price',
#   'maize',
#   'would',
#   '201',
#   '49',
#   'ecus',
#   'tonne'],
#  ['said',
#   'price',
#   'seemed',
#   'unlikely',
#   'full',
#   'added',
#   'decision',
#   'also',
#   'designed',
#   'prevent',
#   'massive',
#   'offers',
#   'maize',
#   'intervention',
#   'ahead',
#   'normal',
#   'april',
#   '30',
#   'deadline',
#   'could',
#   'caused',
#   'speculation',
#   'implementation',
#   'accord',
#   'united',
#   'states'],
#  ['london',
#   'grain',
#   'freights',
#   '27',
#   '000',
#   'long',
#   'tons',
#   'usg',
#   'taiwan',
#   '23',
#   '25',
#   'dlrs',
#   'fio',
#   'five',
#   'days',
#   '1',
#   '500',
#   '1',
#   '10',
#   '5',
#   'continental'],
#  ['trade',
#   'banner',
#   '30',
#   '000',
#   'long',
#   'tons',
#   'grain',
#   'usg',
#   'morocco',
#   '13',
#   '50',
#   'dlrs',
#   '5',
#   '000',
#   '5',
#   '000',
#   'end',
#   'april',
#   'early',
#   'may',
#   'comanav'],
#  ['reference',
#   'new',
#   'york',
#   'grain',
#   'freights',
#   '1',
#   'april',
#   '8',
#   'ship',
#   'brokers',
#   'say',
#   'vessel',
#   'fixed',
#   'cam',
#   'great',
#   'lakes',
#   'algeria',
#   '28',
#   'dlrs',
#   'reported',
#   'vamand',
#   'wave'],
#  ['reference',
#   'new',
#   'york',
#   'grain',
#   'freights',
#   '2',
#   'april',
#   '8',
#   'say',
#   'cory',
#   'grain',
#   'maize',
#   'business',
#   'east',
#   'london',
#   '22',
#   'dlrs',
#   'japan',
#   'spain',
#   'reported'],
#  ['london',
#   'grain',
#   'freight',
#   'enquiries',
#   'antwerp',
#   'libya',
#   '5',
#   '500',
#   'mt',
#   'bagged',
#   'flour',
#   '14',
#   'daps',
#   '24',
#   '27',
#   '4'],
#  ['new',
#   'orleans',
#   'guanta',
#   '9',
#   '387',
#   'mt',
#   'bulk',
#   'hss',
#   '3',
#   '000',
#   '13',
#   'days',
#   '25',
#   '4',
#   '5',
#   '5'],
#  ['naantali',
#   'saudi',
#   'red',
#   'sea',
#   '30',
#   '000',
#   '35',
#   '000',
#   'mt',
#   'barley',
#   '4',
#   '000',
#   '3',
#   '000',
#   '20',
#   '30',
#   '4',
#   'early',
#   'may'],
#  ['dunkirk',
#   'xingang',
#   '12',
#   '000',
#   'mt',
#   'bagged',
#   'flour',
#   '1',
#   '500',
#   '1',
#   '700',
#   '13',
#   '20',
#   '4'],
#  ['toledo',
#   'seaforth',
#   '17',
#   '000',
#   'mt',
#   'hss',
#   'offers',
#   '18',
#   '50',
#   'dlrs',
#   'four',
#   'days',
#   '8',
#   '000',
#   '13',
#   '15',
#   '4'],
#  ['river',
#   'plate',
#   'malaysia',
#   '20',
#   '000',
#   '22',
#   '000',
#   'long',
#   'tons',
#   'hss',
#   '2',
#   '000',
#   '2',
#   '000',
#   'apr'],
#  ['egypt',
#   'cancels',
#   'wheat',
#   'tender',
#   'egypt',
#   'cancelled',
#   'april',
#   '2',
#   'tender',
#   '200',
#   '000',
#   'tonnes',
#   'origin',
#   'wheat',
#   'april',
#   '15',
#   '30',
#   'shipment',
#   'trade',
#   'egyptian',
#   'official',
#   'sources',
#   'said'],
#  ['trade',
#   'sources',
#   'said',
#   'cancellation',
#   'followed',
#   'offer',
#   'egyptian',
#   'company',
#   'islamic',
#   'corp',
#   '85',
#   '80',
#   'dlrs',
#   'tonne',
#   'cost',
#   'freight',
#   'undercutting',
#   'traders',
#   'offers',
#   '93',
#   '90',
#   '94',
#   '49',
#   'dlrs',
#   'tonne'],
#  ['egyptian',
#   'trade',
#   'official',
#   'paris',
#   'confirmed',
#   'cancellation',
#   'tender',
#   'following',
#   'islamic',
#   'corp',
#   'offer',
#   'said',
#   'government',
#   'refused',
#   'legal',
#   'reasons'],
#  ['official',
#   'denied',
#   'trade',
#   'reports',
#   'government',
#   'might',
#   'substituted',
#   'private',
#   'deal',
#   'islamic',
#   'corp',
#   'original',
#   'tender'],
#  ['usda',
#   'estimates',
#   '1986',
#   '87',
#   'ussr',
#   'grain',
#   'imports',
#   '28',
#   '0',
#   'mln',
#   'tonnes',
#   'vs',
#   '26',
#   '0',
#   'march',
#   '29',
#   '9',
#   'year',
#   'ago'],
#  ['usda',
#   'estimates',
#   '1986',
#   '87',
#   'ussr',
#   'grain',
#   'imports',
#   '28',
#   '0',
#   'mln',
#   'tonnes',
#   'vs',
#   '26',
#   '0',
#   'march',
#   '29',
#   '9',
#   'year',
#   'ago'],
#  ['usda',
#   'estimates',
#   '1986',
#   'soviet',
#   'grain',
#   'crop',
#   '210',
#   'mln',
#   'tonnes',
#   'vs',
#   '210',
#   'march',
#   '192',
#   'year',
#   'ago'],
#  ['usda',
#   'estimates',
#   '1986',
#   'soviet',
#   'grain',
#   'crop',
#   '210',
#   'mln',
#   'tonnes',
#   'vs',
#   '210',
#   'march',
#   '192',
#   'year',
#   'ago'],
#  ['usda',
#   'u',
#   '1986',
#   '87',
#   'ending',
#   'corn',
#   'stocks',
#   '5',
#   '240',
#   'mln',
#   'bu',
#   'wheat',
#   '1',
#   '848',
#   'mln',
#   'soybeans',
#   '610',
#   'mln'],
#  ['usda',
#   'u',
#   '1986',
#   '87',
#   'ending',
#   'corn',
#   'stocks',
#   '5',
#   '240',
#   'mln',
#   'bu',
#   'wheat',
#   '1',
#   '848',
#   'mln',
#   'soybeans',
#   '610',
#   'mln'],
#  ['u',
#   'supply',
#   'demand',
#   'highlights',
#   'following',
#   'highlights',
#   'u',
#   'agriculture',
#   'department',
#   'supply',
#   'demand',
#   'projections',
#   '1986',
#   '87',
#   'seasons',
#   'mln',
#   'bushels',
#   'comparisons',
#   'unless',
#   'noted',
#   'corn',
#   'stocks',
#   'aug',
#   '31',
#   '1987',
#   '5',
#   '240',
#   'vs',
#   '5',
#   '595',
#   'last',
#   'month'],
#  ['stocks',
#   'aug',
#   '31',
#   '1986',
#   '4',
#   '040',
#   'vs',
#   '4',
#   '040',
#   'last',
#   'month'],
#  ['exports', 'projected', '1', '375', 'vs', '1', '250', 'last', 'month'],
#  ['exports', '1985', '86', '1', '241', 'vs', '1', '241', 'last', 'month'],
#  ['domestic', 'use', '5', '680', 'vs', '5', '450', 'last', 'month'],
#  ['usage',
#   '1985',
#   '86',
#   'season',
#   '5',
#   '255',
#   'vs',
#   '5',
#   '255',
#   'last',
#   'month'],
#  ['wheat',
#   'stocks',
#   'may',
#   '31',
#   '1987',
#   'projected',
#   '1',
#   '848',
#   'vs',
#   '1',
#   '877',
#   'last',
#   'month'],
#  ['stocks',
#   'may',
#   '31',
#   '1986',
#   '1',
#   '905',
#   'vs',
#   '1',
#   '905',
#   'last',
#   'month'],
#  ['exports',
#   '1986',
#   '87',
#   'season',
#   '1',
#   '025',
#   'vs',
#   '1',
#   '025',
#   'last',
#   'month'],
#  ['1985', '86', 'season', '915', 'vs', '915', 'last', 'month'],
#  ['domestic',
#   'use',
#   '1986',
#   '87',
#   '1',
#   '134',
#   'vs',
#   '1',
#   '105',
#   'last',
#   'month'],
#  ['1985', '86', '1', '045', 'vs', '1', '045', 'last', 'month'],
#  ['cotton',
#   'mln',
#   '480',
#   'lb',
#   'bales',
#   'stocks',
#   'july',
#   '31',
#   '1987',
#   '5',
#   '40',
#   'vs',
#   '5',
#   '49',
#   'last',
#   'month'],
#  ['stocks', 'july', '31', '1986', '9', '35', 'vs', '9', '35', 'last', 'month'],
#  ['exports',
#   '1986',
#   '87',
#   'season',
#   '6',
#   '66',
#   'vs',
#   '6',
#   '76',
#   'last',
#   'month'],
#  ['exports', '1985', '86', '1', '96', 'vs', '1', '96', 'last', 'month'],
#  ['soybeans',
#   'mln',
#   'bushels',
#   'stocks',
#   'aug',
#   '31',
#   '1987',
#   'projected',
#   '610',
#   'vs',
#   '635',
#   'last',
#   'month'],
#  ['stocks', 'aug', '31', '1986', '536', 'vs', '536', 'last', 'month'],
#  ['soybean',
#   'crushings',
#   '1986',
#   '87',
#   '1',
#   '130',
#   'vs',
#   '1',
#   '115',
#   'last',
#   'month'],
#  ['crushings', '1985', '86', '1', '053', 'vs', '1', '053', 'last', 'month'],
#  ['exports', '1986', '87', 'season', '700', 'vs', '700', 'last', 'month'],
#  ['exports', '1985', '86', '740', 'vs', '740', 'last', 'month'],
#  ['soybean',
#   'oil',
#   'mln',
#   'lbs',
#   'stocks',
#   'sept',
#   '30',
#   '1987',
#   '1',
#   '360',
#   'vs',
#   '1',
#   '200',
#   'last',
#   'month'],
#  ['stocks', 'sept', '30', '1986', '947', 'vs', '947', 'last', 'month'],
#  ['exports', '1986', '87', '1', '350', 'vs', '1', '350', 'last', 'month'],
#  ['exports', '1985', '86', '1', '257', 'vs', '1', '257', 'last', 'month'],
#  ['soybean',
#   'cake',
#   'meal',
#   'thousand',
#   'short',
#   'tons',
#   'stocks',
#   'sept',
#   '30',
#   '1987',
#   '270',
#   'vs',
#   '315',
#   'last',
#   'month'],
#  ['stocks', 'sept', '30', '1986', '212', 'vs', '212', 'last', 'month'],
#  ['exports',
#   '1986',
#   '87',
#   'season',
#   '6',
#   '500',
#   'vs',
#   '6',
#   '350',
#   'last',
#   'month'],
#  ['exports', '1985', '86', '6', '036', 'vs', '6', '008', 'last', 'month'],
#  ['ussr',
#   'adds',
#   'u',
#   'corn',
#   'commitments',
#   'usda',
#   'soviet',
#   'union',
#   'added',
#   '175',
#   '600',
#   'tonnes',
#   'u',
#   'corn',
#   'previous',
#   'commitments',
#   'delivery',
#   'fourth',
#   'year',
#   'u',
#   'ussr',
#   'grain',
#   'supply',
#   'agreement',
#   'began',
#   'october',
#   '1',
#   '1986',
#   'u',
#   'agriculture',
#   'department',
#   'said'],
#  ['according',
#   'department',
#   'export',
#   'sales',
#   'report',
#   'covering',
#   'transactions',
#   'week',
#   'ended',
#   'april',
#   '2',
#   'corn',
#   'transactions',
#   'consisted',
#   '140',
#   '600',
#   'tonnes',
#   'new',
#   'sales',
#   'changes',
#   'destinations',
#   '35',
#   '000',
#   'tonnes'],
#  ['total',
#   'corn',
#   'commitments',
#   'ussr',
#   'delivery',
#   'fourth',
#   'agreement',
#   'year',
#   'amount',
#   '2',
#   '825',
#   '600',
#   'tonnes'],
#  ['soviets', 'purchased', 'wheat', 'soybeans', 'fourth', 'year', 'agreement'],
#  ['usda',
#   'details',
#   'free',
#   'grain',
#   'stocks',
#   'loan',
#   'u',
#   'agriculture',
#   'department',
#   'gave',
#   'projected',
#   'carryover',
#   'free',
#   'stocks',
#   'feedgrains',
#   'corn',
#   'wheat',
#   'loans',
#   'comparisons',
#   'follows',
#   'mln',
#   'bushels',
#   'except',
#   'feedgrains',
#   'mln',
#   'tonnes',
#   '1986',
#   '87',
#   '1985',
#   '86',
#   '04',
#   '09',
#   '87',
#   '03',
#   '09',
#   '87',
#   '04',
#   '09',
#   '87',
#   '03',
#   '09',
#   '87',
#   'regular',
#   'nine',
#   'month',
#   'loan',
#   'wheat',
#   '225',
#   '300',
#   '678',
#   '678',
#   'feedgrains',
#   '52',
#   '1',
#   '68',
#   '1',
#   '75',
#   '7',
#   '75',
#   '7',
#   'corn',
#   '1',
#   '800',
#   '2',
#   '400',
#   '2',
#   '589',
#   '2',
#   '589',
#   'special',
#   'producer',
#   'storage',
#   'loan',
#   'program',
#   'wheat',
#   '165',
#   '150',
#   '163',
#   '163',
#   'feedgrains',
#   '7',
#   '0',
#   '6',
#   '7',
#   '5',
#   '3',
#   '5',
#   '3',
#   'corn',
#   '200',
#   '200',
#   '147',
#   '147'],
#  ['usda',
#   'estimates',
#   'soviet',
#   'wheat',
#   'coarse',
#   'grains',
#   'u',
#   'agriculture',
#   'department',
#   'forecast',
#   'soviet',
#   '1986',
#   '87',
#   'wheat',
#   'crop',
#   '92',
#   '30',
#   'mln',
#   'tonnes',
#   'vs',
#   '92',
#   '30',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['put',
#   '1985',
#   '86',
#   'crop',
#   '78',
#   '10',
#   'mln',
#   'tonnes',
#   'vs',
#   '78',
#   '10',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['soviet',
#   '1986',
#   '87',
#   'coarse',
#   'grain',
#   'production',
#   'estimated',
#   '103',
#   '30',
#   'mln',
#   'tonnes',
#   'vs',
#   '103',
#   '30',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['production',
#   '1985',
#   '86',
#   'projected',
#   '99',
#   '99',
#   'mln',
#   'tonnes',
#   'vs',
#   '100',
#   '00',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['ussr',
#   'wheat',
#   'imports',
#   'forecast',
#   '15',
#   '00',
#   'mln',
#   'tonnes',
#   '1986',
#   '87',
#   'vs',
#   '15',
#   '00',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['imports',
#   '1985',
#   '86',
#   'put',
#   '15',
#   '70',
#   'mln',
#   'tonnes',
#   'vs',
#   '15',
#   '70',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['usda',
#   'estimated',
#   'soviet',
#   '1986',
#   '87',
#   'coarse',
#   'grain',
#   'imports',
#   '12',
#   '00',
#   'mln',
#   'tonnes',
#   'vs',
#   '10',
#   '00',
#   'mln',
#   'tonnes',
#   'last',
#   'month',
#   '1985',
#   '86',
#   'imports',
#   '13',
#   '70',
#   'mln',
#   'tonnes',
#   'vs',
#   '13',
#   '70',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['usda',
#   'said',
#   'soviet',
#   'coarse',
#   'grain',
#   'imports',
#   'include',
#   '1986',
#   '87',
#   'corn',
#   'imports',
#   'forecast',
#   '8',
#   '00',
#   'mln',
#   'tonnes',
#   'vs',
#   '6',
#   '00',
#   'mln',
#   'tonnes',
#   'last',
#   'month'],
#  ['corn',
#   'imports',
#   '1985',
#   '86',
#   'estimated',
#   '10',
#   '40',
#   'mln',
#   'tonnes',
#   'vs',
#   '10',
#   '40',
#   'mln',
#   'last',
#   'month'],
#  ['total',
#   'soviet',
#   'grain',
#   'imports',
#   '1986',
#   '87',
#   '28',
#   '0',
#   'mln',
#   'tonnes',
#   'include',
#   'one',
#   'mln',
#   'tonnes',
#   'miscellaneous',
#   'grains'],
#  ['wheat',
#   'class',
#   'breakdown',
#   'u',
#   'agriculture',
#   'department',
#   'gave',
#   '1986',
#   '87',
#   'breakdown',
#   'supply',
#   'distribution',
#   'wheats',
#   'classes',
#   'mln',
#   'bushels',
#   'comparisons',
#   'follows'],
#  ['hard',
#   'winter',
#   '1986',
#   '87',
#   '1985',
#   '86',
#   '04',
#   '09',
#   '87',
#   '03',
#   '09',
#   '87',
#   '04',
#   '09',
#   '87',
#   '03',
#   '09',
#   '87',
#   'start',
#   'stocks',
#   '1',
#   '009',
#   '1',
#   '009',
#   '717',
#   '717',
#   'production',
# ...
#   'trade',
#   'conditions',
#   'japan',
#   'unsatisfied',
#   'japanese',
#   'offers',
#   'compensation'],
#  ['japan',
#   'main',
#   'offers',
#   'improve',
#   'inspection',
#   'systems',
#   'citrus',
#   'fruits',
#   'aid',
#   'ec',
#   'exports',
#   'improve',
#   'tariffs',
#   'farm',
#   'produce',
#   'increase',
#   'tariffs',
#   'leather',
#   'footwear',
#   'offer',
#   'better',
#   'trade',
#   'terms',
#   'spain',
#   'portugal'],
#  ['ec',
#   'external',
#   'trade',
#   'commissioner',
#   'willy',
#   'de',
#   'clercq',
#   'told',
#   'journalists',
#   'maintain',
#   'position',
#   'japanese',
#   'concessions',
#   'enough'],
#  ['hope', 'improvement', 'said'],
#  ['argentina',
#   'sets',
#   'new',
#   'support',
#   'prices',
#   'grains',
#   'argentina',
#   'agriculture',
#   'secretariat',
#   'set',
#   'new',
#   'support',
#   'prices',
#   'grains',
#   'oilseeds',
#   'official',
#   'statement',
#   'said'],
#  ['said',
#   'support',
#   'price',
#   'wheat',
#   'hiked',
#   '300',
#   'australs',
#   'per',
#   'tonne',
#   '250',
#   'previously',
#   'sunflowerseed',
#   'northwestern',
#   'argentina',
#   '450',
#   'australs',
#   '360',
#   'previously'],
#  ['said', 'price', 'went', 'effect', 'monday'],
#  ['secretariat',
#   'said',
#   'support',
#   'price',
#   'sorghum',
#   'increased',
#   '210',
#   'australs',
#   'per',
#   'tonne',
#   '200',
#   'australs',
#   'previously',
#   'maize',
#   '250',
#   'australs',
#   '220',
#   'australs',
#   'previously'],
#  ['ccc',
#   'preparing',
#   'wheat',
#   'catalogue',
#   'kansas',
#   'city',
#   'commodity',
#   'credit',
#   'corp',
#   'office',
#   'preparing',
#   'wheat',
#   'catalogue',
#   'containing',
#   'roughly',
#   '300',
#   'mln',
#   'bushels',
#   'scheduled',
#   'released',
#   'next',
#   'two',
#   'three',
#   'weeks',
#   'ccc',
#   'spokesman',
#   'said'],
#  ['catalogue',
#   'include',
#   'ccc',
#   'stocks',
#   'stored',
#   'terminals',
#   '50',
#   'pct',
#   'stocks',
#   'stored',
#   'country',
#   'elevators',
#   'spokesman',
#   'said'],
#  ['hard',
#   'red',
#   'winter',
#   'wheat',
#   'comprise',
#   'bulk',
#   'stocks',
#   'followed',
#   'spring',
#   'wheat',
#   'said'],
#  ['release',
#   'date',
#   'tentative',
#   'case',
#   'snags',
#   'catalogue',
#   'preparation',
#   'spokesman',
#   'said'],
#  ['u'],
#  ['exporters',
#   'report',
#   '125',
#   '000',
#   'tonnes',
#   'corn',
#   'sold',
#   'ussr',
#   '1987',
#   '88'],
#  ['u'],
#  ['exporters',
#   'report',
#   '125',
#   '000',
#   'tonnes',
#   'corn',
#   'sold',
#   'ussr',
#   '1987',
#   '88'],
#  ['usda',
#   'reports',
#   'corn',
#   'sold',
#   'ussr',
#   'private',
#   'exporters',
#   'reported',
#   'sales',
#   '125',
#   '000',
#   'tonnes',
#   'u',
#   'corn',
#   'soviet',
#   'union',
#   'delivery',
#   '1987',
#   '88',
#   'season',
#   'fifth',
#   'year',
#   'long',
#   'term',
#   'grain',
#   'supply',
#   'agreement'],
#  ['department',
#   'noted',
#   'sales',
#   'first',
#   'reported',
#   'delivery',
#   'fifth',
#   'year',
#   'agreement',
#   'began',
#   'october',
#   '1',
#   '1987'],
#  ['sales',
#   'wheat',
#   'corn',
#   'ussr',
#   'delivery',
#   'fourth',
#   'year',
#   'agreement',
#   'totaled',
#   '8',
#   '182',
#   '500',
#   'tonnes',
#   '4',
#   '080',
#   '500',
#   'tonnes',
#   'wheat',
#   '4',
#   '102',
#   '300',
#   'tonnes',
#   'corn'],
#  ['addition', 'sales', 'soybeans', 'totaled', '68', '200', 'tonnes', 'said'],
#  ['spain',
#   'appeals',
#   'ec',
#   'help',
#   'maize',
#   'imports',
#   'spanish',
#   'farm',
#   'minister',
#   'carlos',
#   'romero',
#   'speaking',
#   'meeting',
#   'ec',
#   'farm',
#   'ministers',
#   'called',
#   'action',
#   'help',
#   'spanish',
#   'maize',
#   'market',
#   'spanish',
#   'diplomatic',
#   'sources',
#   'said'],
#  ['spain',
#   'threatened',
#   'massive',
#   'imports',
#   'third',
#   'countries',
#   'end',
#   'year',
#   'said'],
#  ['said',
#   'imports',
#   'due',
#   'come',
#   'result',
#   'accord',
#   'ec',
#   'promised',
#   'united',
#   'states',
#   'import',
#   'two',
#   'mln',
#   'tonnes',
#   'maize',
#   '300',
#   '000',
#   'tonnes',
#   'sorghum',
#   'spain',
#   'third',
#   'countries',
#   'year'],
#  ['around',
#   'sixth',
#   'tonnage',
#   'far',
#   'come',
#   'reduced',
#   'levy',
#   'system',
#   'ec',
#   'cereals',
#   'management',
#   'committee',
#   'may',
#   'decide',
#   'week',
#   'authorise',
#   'spanish',
#   'intervention',
#   'board',
#   'make',
#   'direct',
#   'purchases'],
#  ['sources',
#   'said',
#   'romero',
#   'urged',
#   'ec',
#   'countries',
#   'take',
#   'imports',
#   'prevent',
#   'disturbance',
#   'spanish',
#   'market'],
#  ['said',
#   'threatened',
#   'withhold',
#   'support',
#   'ec',
#   'commission',
#   'plan',
#   'new',
#   'limits',
#   'farm',
#   'output',
#   'breached',
#   'would',
#   'mean',
#   'price',
#   'cuts',
#   'unless',
#   'spain',
#   'received',
#   'help'],
#  ['sources', 'said', 'direct', 'reply', 'given', 'romero', 'meeting'],
#  ['el',
#   'salvador',
#   'seeking',
#   'pl',
#   '480',
#   'soymeal',
#   'corn',
#   'el',
#   'salvador',
#   'tender',
#   'october',
#   '26',
#   'approximately',
#   '26',
#   '000',
#   'tonnes',
#   'soybean',
#   'meal',
#   'valued',
#   '5',
#   '6',
#   'mln',
#   'dlrs',
#   '24',
#   '500',
#   'tonnes',
#   'bulk',
#   'corn',
#   'value',
#   '2',
#   '0',
#   'mln',
#   'dlrs',
#   'pl',
#   '480',
#   'financing',
#   'agent',
#   'country',
#   'said'],
#  ['said',
#   'country',
#   'seeking',
#   'soymeal',
#   '48',
#   'pct',
#   'protein',
#   'minimum',
#   '12',
#   'pct',
#   'moisture',
#   'maximum',
#   '3',
#   '5',
#   'pct',
#   'maximum',
#   'crude',
#   'fiber',
#   'delivery',
#   'november',
#   '15',
#   '30'],
#  ['u'],
#  ['2',
#   'better',
#   'yellow',
#   'corn',
#   '14',
#   '5',
#   'pct',
#   'moisture',
#   'maximum',
#   'delivery',
#   'november',
#   '8',
#   '25'],
#  ['offers',
#   'soymeal',
#   'corn',
#   'due',
#   '1530',
#   'hrs',
#   'edt',
#   '1930',
#   'gmt',
#   'oct',
#   '26',
#   'remain',
#   'valid',
#   '1000',
#   'hrs',
#   'edt',
#   'next',
#   'day',
#   'agent',
#   'said'],
#  ['algeria',
#   'tendering',
#   'balance',
#   'eep',
#   'wheat',
#   'trade',
#   'algeria',
#   'tendering',
#   'tonight',
#   '225',
#   '000',
#   'tonnes',
#   'hard',
#   'red',
#   'winter',
#   'wheat',
#   '94',
#   '00',
#   'dlrs',
#   'per',
#   'tonne',
#   'c',
#   'f',
#   'balance',
#   'original',
#   'tender',
#   'export',
#   'bonus',
#   'program',
#   'u',
#   'exporters',
#   'said'],
#  ['algeria',
#   'bought',
#   '75',
#   '000',
#   'tonnes',
#   'november',
#   'early',
#   'december',
#   'shipmet',
#   'bid',
#   'usda',
#   'rejected',
#   'bid',
#   'wheat',
#   'later',
#   'shipments',
#   'sources',
#   'said'],
#  ['canada',
#   'panel',
#   'advises',
#   'cutting',
#   'u',
#   'corn',
#   'duty',
#   'canadian',
#   'import',
#   'tribunal',
#   'said',
#   'countervailing',
#   'duty',
#   'u',
#   'corn',
#   'imports',
#   'cut',
#   '30',
#   'canadian',
#   'cts',
#   'bushel',
#   '1',
#   '10',
#   'dlrs',
#   'bushel'],
#  ['report',
#   'canadian',
#   'finance',
#   'department',
#   'tribunal',
#   'said',
#   'duty',
#   'hurting',
#   'canadian',
#   'farmers',
#   'food',
#   'processors'],
#  ['duty',
#   'imposed',
#   'last',
#   'year',
#   'revenue',
#   'department',
#   'found',
#   'u',
#   'corn',
#   'production',
#   'subsidized'],
#  ['government', 'decide', 'whether', 'change', 'duty'],
#  ['u'],
#  ['export',
#   'inspections',
#   'thous',
#   'bushels',
#   'soybeans',
#   '16',
#   '333',
#   'wheat',
#   '30',
#   '917',
#   'corn',
#   '36',
#   '781'],
#  ['u'],
#  ['export',
#   'inspections',
#   'thous',
#   'bushels',
#   'soybeans',
#   '16',
#   '333',
#   'wheat',
#   '30',
#   '917',
#   'corn',
#   '36',
#   '781'],
#  ['soviet',
#   '1988',
#   'grain',
#   'target',
#   'indicates',
#   '1987',
#   'output',
#   'recent',
#   'announcements',
#   'moscow',
#   'next',
#   'year',
#   'grain',
#   'production',
#   'targets',
#   'indicate',
#   'soviets',
#   'estimating',
#   'year',
#   'grain',
#   'crop',
#   '205',
#   '213',
#   'mln',
#   'tonnes',
#   'agriculture',
#   'department',
#   'analysts',
#   'said'],
#  ['usda',
#   'projecting',
#   'soviet',
#   'crop',
#   '210',
#   'mln',
#   'tonnes',
#   'earlier',
#   'estimates',
#   'soviet',
#   'officials',
#   '1987',
#   'grain',
#   'crop',
#   'could',
#   'match',
#   '1978',
#   'record',
#   '237',
#   'mln',
#   'tonnes'],
#  ['moscow',
#   'outlined',
#   'economic',
#   'targets',
#   '1988',
#   'monday',
#   'putting',
#   'grain',
#   'harvest',
#   'goal',
#   '235',
#   'mln',
#   'tonnes'],
#  ['analyst',
#   'soviet',
#   'agriculture',
#   'usda',
#   'noted',
#   'recent',
#   'article',
#   'izvestia',
#   'said',
#   'soviet',
#   'grain',
#   'production',
#   '1988',
#   'planned',
#   '25',
#   '30',
#   'mln',
#   'tonnes',
#   'expected',
#   'year'],
#  ['indicates',
#   'estimate',
#   '205',
#   '213',
#   'mln',
#   'tonne',
#   'grain',
#   'crop',
#   'analyst',
#   'said'],
#  ['calculating',
#   'moscow',
#   'crop',
#   'estimate',
#   'usda',
#   'used',
#   '235',
#   'mln',
#   'tonne',
#   'production',
#   'goal',
#   'well',
#   '238',
#   'mln',
#   'tonne',
#   'figure',
#   'published',
#   'soviet',
#   'economic',
#   'journal',
#   'month'],
#  ['usda',
#   'production',
#   'estimate',
#   '210',
#   'mln',
#   'tonnes',
#   'reflects',
#   'range',
#   '207',
#   '212',
#   'mln',
#   'tonnes',
#   'usda',
#   'source',
#   'said'],
#  ['late',
#   'season',
#   'rains',
#   'damaged',
#   'soviet',
#   'crops',
#   'slowed',
#   'harvest',
#   'progress',
#   'lowered',
#   'soviet',
#   'production',
#   'analysts',
#   'said'],
#  ['u',
#   'earlier',
#   'month',
#   'soviet',
#   'agriculture',
#   'official',
#   'viktor',
#   'nikonov',
#   'predicted',
#   'grain',
#   'crop',
#   'would',
#   'good',
#   'better',
#   'last',
#   'year',
#   '210',
#   'mln',
#   'tonne',
#   'harvest'],
#  ['member',
#   'nikonov',
#   'party',
#   'commented',
#   'although',
#   '230',
#   'mln',
#   'tonnes',
#   'grain',
#   'fields',
#   'harvest',
#   'problems',
#   'would',
#   'bring',
#   'final',
#   'crop',
#   'around',
#   '210',
#   'mln',
#   'tonnes'],
#  ['u',
#   'senate',
#   'panel',
#   'votes',
#   'limit',
#   'county',
#   'loan',
#   'drop',
#   'senate',
#   'agriculture',
#   'committee',
#   'voted',
#   'limit',
#   'changes',
#   'county',
#   'loan',
#   'rate',
#   'differentials',
#   'starting',
#   '1988',
#   'crop',
#   'part',
#   'budget',
#   'deficit',
#   'reduction',
#   'package'],
#  ['panel',
#   'also',
#   'approved',
#   'measures',
#   'could',
#   'trigger',
#   'larger',
#   'corn',
#   'wheat',
#   'acreage',
#   'reduction',
#   'requirements',
#   'increase',
#   'farmer',
#   'held',
#   'reserve',
#   'storage',
#   'payments',
#   'reduce',
#   'potential',
#   'milk',
#   'support',
#   'price',
#   'cut',
#   'require',
#   'advance',
#   'deficiency',
#   'payments',
#   'producers',
#   'major',
#   'crops'],
#  ['proposal',
#   'require',
#   'imported',
#   'tropical',
#   'oils',
#   'labeled',
#   'u',
#   'food',
#   'products',
#   'failed',
#   '10',
#   '8',
#   'vote'],
#  ['u',
#   'senate',
#   'panel',
#   'votes',
#   'limit',
#   'county',
#   'loan',
#   'rate',
#   'changes',
#   'starting',
#   '1988',
#   'crops'],
#  ['u',
#   'senate',
#   'panel',
#   'votes',
#   'limit',
#   'county',
#   'loan',
#   'rate',
#   'changes',
#   'starting',
#   '1988',
#   'crops'],
#  ['senate',
#   'panel',
#   'studies',
#   'loan',
#   'rate',
#   'set',
#   'aside',
#   'plans',
#   'senate',
#   'agriculture',
#   'committee',
#   'expected',
#   'consider',
#   'proposals',
#   'would',
#   'limit',
#   'adjustments',
#   'county',
#   'loan',
#   'rate',
#   'differentials',
#   'trigger',
#   'larger',
#   'corn',
#   'wheat',
#   'acreage',
#   'reduction',
#   'requirements',
#   'senate',
#   'staff',
#   'said'],
#  ['budget',
#   'saving',
#   'proposal',
#   'drafted',
#   'chairman',
#   'patrick',
#   'leahy',
#   'vt',
#   'would',
#   'limit',
#   'adjustments',
#   'county',
#   'loan',
#   'rate',
#   'differentials',
#   'one',
#   'pct',
#   'per',
#   'year',
#   'national',
#   'average',
#   'loan',
#   'rate',
#   'starting',
#   '1988',
#   'crops'],
#  ['plan',
#   'also',
#   'would',
#   'allow',
#   'agriculture',
#   'secretary',
#   'increase',
#   'unpaid',
#   'acreage',
#   'reduction',
#   'requirement',
#   'corn',
#   'appropriate',
#   'amount',
#   'generate',
#   'savings',
#   'projected',
#   'corn',
#   'stocks',
#   'exceeded',
#   '6',
#   '0',
#   'billion',
#   'bushels'],
#  ['leahy',
#   'proposal',
#   'would',
#   'also',
#   'allow',
#   'larger',
#   '1988',
#   'wheat',
#   'set',
#   'aside',
#   'projected',
#   'stocks',
#   'surpassed',
#   '1',
#   '9',
#   'billion',
#   'bushels'],
#  ['soviets',
#   'outline',
#   '1988',
#   'economic',
#   'targets',
#   'soviet',
#   'union',
#   'outlined',
#   'economic',
#   'targets',
#   '1988',
#   'monday',
#   'stressing',
#   'need',
#   'improve',
#   'standards',
#   'country',
#   'sluggish',
#   'engineering',
#   'industry'],
#  ['planning',
#   'chief',
#   'nikolai',
#   'talyzin',
#   'told',
#   'supreme',
#   'soviet',
#   'industrial',
#   'output',
#   'rise',
#   '4',
#   '5',
#   'pct',
#   '1988',
#   'planned',
#   '4',
#   '4',
#   'pct',
#   '1987'],
#  ['rose', '3', '6', 'pct', 'jan', 'sept', '1987'],
#  ['talyzin',
#   'said',
#   'national',
#   'income',
#   'nearest',
#   'soviet',
#   'equivalent',
#   'gross',
#   'national',
#   'product',
#   'rise',
#   '4',
#   '3',
#   'pct',
#   'planned',
#   '4',
#   '1',
#   'pct',
#   'year'],
#  ['gross',
#   'national',
#   'product',
#   'measures',
#   'output',
#   'country',
#   'goods',
#   'services'],
#  ['said',
#   'kremlin',
#   'planned',
#   'produce',
#   '235',
#   'mln',
#   'tonnes',
#   'grain',
#   '1988',
#   'versus',
#   'planned',
#   '232',
#   'mln',
#   'year'],
#  ['moscow', 'produced', '210', 'mln', 'tonnes', '1986'],
#  ['kremlin',
#   'leader',
#   'mikhail',
#   'gorbachev',
#   'described',
#   'machine',
#   'builing',
#   'sector',
#   'whose',
#   'rapid',
#   'modernization',
#   'essential',
#   'soviet',
#   'union',
#   'compete',
#   'effectively',
#   'world',
#   'markets'],
#  ['certain',
#   'difficulties',
#   'arisen',
#   'year',
#   'machine',
#   'building',
#   'industry'],
#  ['economy',
#   'receiving',
#   'considerable',
#   'amount',
#   'equipment',
#   'requires',
#   'said',
#   'talyzin',
#   'heads',
#   'state',
#   'planning',
#   'committee',
#   'gosplan'],
#  ['soviet',
#   'data',
#   'show',
#   'machine',
#   'building',
#   'industry',
#   'makes',
#   'machine',
#   'tools',
#   'instruments',
#   'engineering',
#   'goods',
#   'increased',
#   'output',
#   '3',
#   '3',
#   'pct',
#   'first',
#   'nine',
#   'months',
#   '1987',
#   'compared',
#   'period',
#   'last',
#   'year'],
#  ['however',
#   'far',
#   '7',
#   '3',
#   'pct',
#   'increase',
#   'planned',
#   'industry',
#   'whole',
#   '1988'],
#  ['talyzin',
#   'said',
#   'ruling',
#   'politburo',
#   'concluded',
#   'recent',
#   'meeting',
#   'improvement',
#   'economic',
#   'performance',
#   'depended',
#   'large',
#   'extent',
#   'conserving',
#   'resources',
#   'better'],
#  ['large', 'scale', 'measures', 'planned', 'save', 'resources', 'said'],
#  ['finance',
#   'minister',
#   'boris',
#   'gostev',
#   'told',
#   'supreme',
#   'soviet',
#   'defense',
#   'spending',
#   '1988',
#   'would',
#   'total',
#   '32',
#   'billion',
#   'dlrs',
#   'figure',
#   'announced',
#   'last',
#   'year'],
#  ['western',
#   'governments',
#   'view',
#   'official',
#   'soviet',
#   'estimates',
#   'defense',
#   'spending',
#   'highly',
#   'understated',
#   'say',
#   'real',
#   'figure',
#   'hard',
#   'calculate',
#   'soviet',
#   'military',
#   'industries',
#   'intertwined',
#   'civilian',
#   'economy'],
#  ['talyzin',
#   'said',
#   'kremlin',
#   'also',
#   'decided',
#   'increase',
#   'spending',
#   'next',
#   'year',
#   'medical',
#   'services',
#   'education',
#   'pensions',
#   'social',
#   'insurance',
#   'schemes'],
#  ['thai',
#   'traders',
#   'plan',
#   'maize',
#   'futures',
#   'market',
#   'thai',
#   'traders',
#   'plan',
#   'establish',
#   'company',
#   'regulate',
#   'maize',
#   'forward',
#   'trading',
#   'could',
#   'first',
#   'step',
#   'towards',
#   'commodities',
#   'futures',
#   'exchange',
#   'maize',
#   'dealers',
#   'said'],
#  ['traders',
#   'internal',
#   'trade',
#   'department',
#   'officials',
#   'agreed',
#   'last',
#   'week',
#   'commission',
#   'study',
#   'structure',
#   'regulate',
#   'maize',
#   'forward',
#   'trading',
#   'set',
#   'company',
#   'thailand',
#   'commodity',
#   'exchange',
#   'co',
#   'ltd',
#   '30',
#   'businesses',
#   'shareholders',
#   'act',
#   'brokers',
#   'futures',
#   'market'],
#  ['chanthong',
#   'pattamapong',
#   'commodities',
#   'trader',
#   'asked',
#   'draw',
#   'study',
#   'said',
#   'maize',
#   'futures',
#   'market',
#   'succeeds',
#   'may',
#   'extended',
#   'commodities',
#   'perhaps',
#   'sugar',
#   'rubber'],
#  ['china',
#   'forecasts',
#   '397',
#   'mln',
#   'tonnes',
#   'grain',
#   'harvest',
#   'china',
#   'expects',
#   '1987',
#   'grain',
#   'harvest',
#   '397',
#   'mln',
#   'tonnes',
#   'eight',
#   'mln',
#   'tonnes',
#   'short',
#   'target',
#   'new',
#   'china',
#   'news',
#   'agency',
#   'quoted',
#   'state',
#   'statistical',
#   'bureau',
#   'spokesman',
#   'saying'],
#  ['harvest',
#   'china',
#   'second',
#   'highest',
#   'history',
#   'poor',
#   'weather',
#   'low',
#   'incentives',
#   'grain',
#   'producing',
#   'farmers',
#   'kept',
#   'yields',
#   'earlier',
#   'chinese',
#   'press',
#   'reports',
#   'said'],
#  ['industry',
#   'sources',
#   'expect',
#   'china',
#   'import',
#   'least',
#   '10',
#   'mln',
#   'tonnes',
#   'grain',
#   'year',
#   'harvest',
#   'shortfall'],
#  ...]

# %%
len(cleaned_corpus)
# Out:
# 4113

# %%
# Custom callback to log loss and time every 100 epochs
class EpochLogger(CallbackAny2Vec):
    def __init__(self):
        self.epoch = 0  # Initialize epoch counter
        self.start_time = time.time()  # Record the start time
        self.previous_loss = 0  # Track the previous cumulative loss

    def on_epoch_end(self, model):
        self.epoch += 1  # Increment epoch counter
        if self.epoch % 100 == 0:  # Log every 100 epochs
            elapsed_time = time.time() - self.start_time  # Calculate elapsed time
            cumulative_loss = model.get_latest_training_loss()  # Get cumulative loss
            epoch_loss = cumulative_loss - self.previous_loss  # Calculate per-epoch loss
            self.previous_loss = cumulative_loss  # Update previous loss for next calculation
            print(f"Epoch {self.epoch:5} | Loss: {epoch_loss:.6f} | Time: {int(elapsed_time // 60)}m {int(elapsed_time % 60)}s")

# %%
# Training parameters
window_size = 2  # Context window size
emb_size = 2  # Embedding size
min_count = 2  # Ignore words with frequency less than min_count

# Initialize the callback
epoch_logger = EpochLogger()

# Train the Word2Vec model with the callback
model = Word2Vec(
    sentences=cleaned_corpus,  # Corpus to train on
    vector_size=emb_size,  # Size of the word embeddings
    window=window_size,  # Context window size
    min_count=min_count,  # Minimum word frequency threshold
    workers=22,  # Number of worker threads for parallel processing
    epochs=1000,  # Number of training epochs
    compute_loss=True,  # Enable loss computation
    callbacks=[epoch_logger]  # Add the callback for logging
    )
# Out:
# Epoch   100 | Loss: 2070179.125000 | Time: 0m 3s
# Epoch   200 | Loss: 1990935.375000 | Time: 0m 6s
# Epoch   300 | Loss: 1872034.500000 | Time: 0m 9s
# Epoch   400 | Loss: 1874788.000000 | Time: 0m 13s
# Epoch   500 | Loss: 1521846.000000 | Time: 0m 16s
# Epoch   600 | Loss: 1355779.000000 | Time: 0m 19s
# Epoch   700 | Loss: 1351014.000000 | Time: 0m 23s
# Epoch   800 | Loss: 1341355.000000 | Time: 0m 26s
# Epoch   900 | Loss: 1335077.000000 | Time: 0m 29s
# Epoch  1000 | Loss: 1329423.000000 | Time: 0m 32s

# %% [markdown]
# ## Save the model and Args

# %%
# Save the model
model_save_path = 'model/gensim_glove.pkl'
pickle.dump(model,open(model_save_path,'wb'))
